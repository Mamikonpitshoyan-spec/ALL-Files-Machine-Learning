# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../DATA/cluster_blobs.csv')

# %%
df
# Out:
#             X1        X2
# 0     4.645333  6.822294
# 1     4.784032  6.422883
# 2    -5.851786  5.774331
# 3    -7.459592  6.456415
# 4     4.918911  6.961479
# ...        ...       ...
# 1495  0.882673 -6.786272
# 1496  0.946854 -7.254512
# 1497  3.180138  6.608660
# 1498  5.454552  6.461246
# 1499 -7.769230  7.014384
#
# [1500 rows x 2 columns]

# %%
sns.scatterplot(x=df['X1'], y=df['X2'])
# Out:
# <Axes: xlabel='X1', ylabel='X2'>

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=3)

# %%
y = model.fit_predict(df)

# %%
df['y'] = y

# %%
df
# Out:
#             X1        X2  y
# 0     4.645333  6.822294  2
# 1     4.784032  6.422883  2
# 2    -5.851786  5.774331  0
# 3    -7.459592  6.456415  0
# 4     4.918911  6.961479  2
# ...        ...       ... ..
# 1495  0.882673 -6.786272  1
# 1496  0.946854 -7.254512  1
# 1497  3.180138  6.608660  2
# 1498  5.454552  6.461246  2
# 1499 -7.769230  7.014384  0
#
# [1500 rows x 3 columns]

# %%
sns.scatterplot(x=df['X1'], y=df['X2'], hue=df['y'])
# Out:
# <Axes: xlabel='X1', ylabel='X2'>

# %%
df['...'] = df['...'].replace(to_replace='', value='')
