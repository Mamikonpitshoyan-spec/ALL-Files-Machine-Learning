# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../DATA/gene_expression.csv')

# %%
df = df[['Gene One', 'Cancer Present']]

# %%
sns.scatterplot(x=df['Gene One'], y=df['Cancer Present'])
# Out:
# <Axes: xlabel='Gene One', ylabel='Cancer Present'>

# %%
X = df.drop('Cancer Present', axis=1)
y = df['Cancer Present']

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X, y)
# Out:
# LogisticRegression()

# %%
model.coef_
# Out:
# array([[0.79738881]])

# %%
model.intercept_
# Out:
# array([-4.46054878])
