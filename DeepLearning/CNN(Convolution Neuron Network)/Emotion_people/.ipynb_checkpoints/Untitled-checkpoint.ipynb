# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import os

# %%
os.listdir('train/')
# Out:
# ['angry', 'disgusted', 'fearful', 'happy', 'neutral', 'sad', 'surprised']

# %%
temp_image = mpimg.imread('test/disgusted/im1.png')

# %%
temp_image.shape
# Out:
# (48, 48)

# %%
temp_image = mpimg.imread('train/angry/im1.png')

# %%
temp_image.shape
# Out:
# (48, 48)

# %%
temp_image = mpimg.imread('train/disgusted/im1.png')

# %%
temp_image.shape
# Out:
# (48, 48)

# %%
temp_image = mpimg.imread('train/fearful/im1.png')

# %%
temp_image.shape
# Out:
# (48, 48)

# %%
temp_image = mpimg.imread('train/happy/im0.png')

# %%
temp_image.shape
# Out:
# (48, 48)

# %%
temp_image = mpimg.imread('train/happy/im1.png')

# %%
temp_image.shape
# Out:
# (48, 48)

# %%
plt.imshow(temp_image)

# %%
data = {
    'angry':0,
    'disgusted':1,
    'fearful':2,
    'happy':3,
    'neutral':4,
    'sad':5,
    'surprised':6
}

# %%
X_train = []
y_train = []
for i in os.listdir('train/'):
    for j in os.listdir(f'train/{i}/'):
        try:
            
            image = cv2.imread(f'train/{i}/{j}')
            image = cv2.resize(image, (48, 48))
            image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            image = image.reshape(48, 48, 1)
            X_train.append(image)
            y_train.append(data[i])

        except:
            continue

X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
data2 = {
    'angry':0,
    'disgusted':1,
    'fearful':2,
    'happy':3,
    'neutral':4,
    'sad':5,
    'surprised':6
}

# %%
X_test = []
y_test = []

for i in os.listdir('test/'):
    for j in os.listdir(f'test/{i}/'):
        try:
            image = cv2.imread(f'test/{i}/{j}')
            image = cv2.resize(image, (48, 48))
            image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            image = image.reshape(48, 48, 1)
    
            X_test.append(image)
            y_test.append(data2[i])
        except:
            continue

X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
X_train
# Out:
# array([[[[ 70],
#          [ 80],
#          [ 82],
#          ...,
#          [ 52],
#          [ 43],
#          [ 41]],
#
#         [[ 65],
#          [ 61],
#          [ 58],
#          ...,
#          [ 56],
#          [ 52],
#          [ 44]],
#
#         [[ 50],
#          [ 43],
#          [ 54],
#          ...,
#          [ 49],
#          [ 56],
#          [ 47]],
#
#         ...,
#
#         [[ 91],
#          [ 65],
#          [ 42],
#          ...,
#          [ 72],
#          [ 56],
#          [ 43]],
#
#         [[ 77],
#          [ 82],
#          [ 79],
#          ...,
#          [105],
#          [ 70],
#          [ 46]],
#
#         [[ 77],
#          [ 72],
#          [ 84],
#          ...,
#          [106],
#          [109],
#          [ 82]]],
#
#
#        [[[151],
#          [150],
#          [147],
#          ...,
#          [129],
#          [140],
#          [120]],
#
#         [[151],
#          [149],
#          [149],
#          ...,
#          [122],
#          [141],
#          [137]],
#
#         [[151],
#          [151],
#          [156],
#          ...,
#          [109],
#          [123],
#          [146]],
#
#         ...,
#
#         [[188],
#          [188],
#          [121],
#          ...,
#          [185],
#          [185],
#          [186]],
#
#         [[188],
#          [187],
#          [196],
#          ...,
#          [186],
#          [182],
#          [187]],
#
#         [[186],
#          [184],
#          [185],
#          ...,
#          [193],
#          [183],
#          [184]]],
#
#
#        [[[117],
#          [116],
#          [113],
#          ...,
#          [ 45],
#          [ 45],
#          [ 45]],
#
#         [[118],
#          [116],
#          [114],
#          ...,
#          [ 46],
#          [ 46],
#          [ 45]],
#
#         [[118],
#          [117],
#          [115],
#          ...,
#          [ 45],
#          [ 46],
#          [ 46]],
#
#         ...,
#
#         [[ 30],
#          [ 29],
#          [ 29],
#          ...,
#          [ 58],
#          [ 55],
#          [ 55]],
#
#         [[ 31],
#          [ 28],
#          [ 28],
#          ...,
#          [ 50],
#          [ 52],
#          [ 54]],
#
#         [[ 33],
#          [ 28],
#          [ 28],
#          ...,
#          [ 46],
#          [ 47],
#          [ 49]]],
#
#
#        ...,
#
#
#        [[[ 10],
#          [ 16],
#          [ 19],
#          ...,
#          [162],
#          [144],
#          [119]],
#
#         [[ 13],
#          [ 16],
#          [ 21],
#          ...,
#          [165],
#          [154],
#          [128]],
#
#         [[ 14],
#          [ 17],
#          [ 19],
#          ...,
#          [168],
#          [165],
#          [136]],
#
#         ...,
#
#         [[ 14],
#          [ 34],
#          [ 37],
#          ...,
#          [176],
#          [164],
#          [156]],
#
#         [[ 15],
#          [ 18],
#          [ 42],
#          ...,
#          [173],
#          [163],
#          [155]],
#
#         [[ 21],
#          [  5],
#          [ 31],
#          ...,
#          [174],
#          [159],
#          [147]]],
#
#
#        [[[141],
#          [148],
#          [156],
#          ...,
#          [197],
#          [193],
#          [193]],
#
#         [[149],
#          [152],
#          [161],
#          ...,
#          [197],
#          [194],
#          [194]],
#
#         [[156],
#          [160],
#          [168],
#          ...,
#          [199],
#          [197],
#          [197]],
#
#         ...,
#
#         [[100],
#          [ 90],
#          [ 74],
#          ...,
#          [224],
#          [223],
#          [223]],
#
#         [[ 83],
#          [ 66],
#          [ 73],
#          ...,
#          [222],
#          [221],
#          [220]],
#
#         [[ 60],
#          [ 57],
#          [ 69],
#          ...,
#          [221],
#          [218],
#          [218]]],
#
#
#        [[[120],
#          [120],
#          [124],
#          ...,
#          [ 78],
#          [ 52],
#          [ 43]],
#
#         [[118],
#          [121],
#          [124],
#          ...,
#          [ 87],
#          [ 66],
#          [ 43]],
#
#         [[118],
#          [118],
#          [124],
#          ...,
#          [ 96],
#          [ 80],
#          [ 55]],
#
#         ...,
#
#         [[185],
#          [162],
#          [131],
#          ...,
#          [188],
#          [202],
#          [204]],
#
#         [[196],
#          [185],
#          [156],
#          ...,
#          [178],
#          [188],
#          [199]],
#
#         [[207],
#          [198],
#          [180],
#          ...,
#          [185],
#          [180],
#          [183]]]], shape=(28709, 48, 48, 1), dtype=uint8)

# %%
y_train
# Out:
# array([0, 0, 0, ..., 6, 6, 6], shape=(28709,))

# %%
X_test
# Out:
# array([[[[254],
#          [254],
#          [254],
#          ...,
#          [ 16],
#          [  0],
#          [161]],
#
#         [[254],
#          [254],
#          [254],
#          ...,
#          [ 17],
#          [  0],
#          [122]],
#
#         [[254],
#          [254],
#          [254],
#          ...,
#          [ 26],
#          [  0],
#          [114]],
#
#         ...,
#
#         [[ 66],
#          [ 86],
#          [ 99],
#          ...,
#          [255],
#          [252],
#          [254]],
#
#         [[ 84],
#          [ 92],
#          [ 92],
#          ...,
#          [236],
#          [255],
#          [255]],
#
#         [[ 93],
#          [ 90],
#          [ 85],
#          ...,
#          [ 42],
#          [129],
#          [180]]],
#
#
#        [[[176],
#          [177],
#          [170],
#          ...,
#          [ 94],
#          [ 87],
#          [108]],
#
#         [[181],
#          [180],
#          [180],
#          ...,
#          [ 98],
#          [ 89],
#          [ 97]],
#
#         [[178],
#          [182],
#          [187],
#          ...,
#          [ 95],
#          [ 95],
#          [ 87]],
#
#         ...,
#
#         [[135],
#          [140],
#          [146],
#          ...,
#          [148],
#          [152],
#          [156]],
#
#         [[144],
#          [139],
#          [155],
#          ...,
#          [152],
#          [160],
#          [162]],
#
#         [[152],
#          [141],
#          [149],
#          ...,
#          [130],
#          [144],
#          [141]]],
#
#
#        [[[ 26],
#          [ 34],
#          [ 23],
#          ...,
#          [134],
#          [136],
#          [135]],
#
#         [[ 35],
#          [ 33],
#          [ 12],
#          ...,
#          [134],
#          [137],
#          [136]],
#
#         [[ 31],
#          [ 17],
#          [ 10],
#          ...,
#          [137],
#          [137],
#          [138]],
#
#         ...,
#
#         [[200],
#          [195],
#          [190],
#          ...,
#          [ 79],
#          [ 81],
#          [ 82]],
#
#         [[197],
#          [192],
#          [186],
#          ...,
#          [ 75],
#          [ 85],
#          [ 86]],
#
#         [[193],
#          [187],
#          [183],
#          ...,
#          [103],
#          [ 81],
#          [ 88]]],
#
#
#        ...,
#
#
#        [[[233],
#          [206],
#          [138],
#          ...,
#          [167],
#          [161],
#          [168]],
#
#         [[239],
#          [233],
#          [133],
#          ...,
#          [173],
#          [170],
#          [174]],
#
#         [[243],
#          [214],
#          [ 95],
#          ...,
#          [148],
#          [162],
#          [171]],
#
#         ...,
#
#         [[ 56],
#          [ 48],
#          [ 52],
#          ...,
#          [170],
#          [150],
#          [153]],
#
#         [[ 60],
#          [ 48],
#          [ 58],
#          ...,
#          [160],
#          [135],
#          [137]],
#
#         [[ 59],
#          [ 46],
#          [ 63],
#          ...,
#          [142],
#          [138],
#          [134]]],
#
#
#        [[[212],
#          [212],
#          [212],
#          ...,
#          [207],
#          [206],
#          [207]],
#
#         [[211],
#          [211],
#          [211],
#          ...,
#          [206],
#          [207],
#          [207]],
#
#         [[212],
#          [211],
#          [210],
#          ...,
#          [207],
#          [207],
#          [207]],
#
#         ...,
#
#         [[161],
#          [ 37],
#          [  0],
#          ...,
#          [ 32],
#          [ 54],
#          [ 92]],
#
#         [[107],
#          [ 39],
#          [ 71],
#          ...,
#          [ 60],
#          [ 20],
#          [  2]],
#
#         [[ 30],
#          [ 41],
#          [ 64],
#          ...,
#          [186],
#          [159],
#          [105]]],
#
#
#        [[[167],
#          [167],
#          [171],
#          ...,
#          [ 67],
#          [ 61],
#          [ 53]],
#
#         [[167],
#          [167],
#          [170],
#          ...,
#          [ 51],
#          [ 52],
#          [ 54]],
#
#         [[168],
#          [166],
#          [161],
#          ...,
#          [ 59],
#          [ 56],
#          [ 52]],
#
#         ...,
#
#         [[ 65],
#          [ 63],
#          [ 69],
#          ...,
#          [103],
#          [102],
#          [100]],
#
#         [[ 51],
#          [ 75],
#          [ 66],
#          ...,
#          [ 97],
#          [104],
#          [108]],
#
#         [[ 57],
#          [ 77],
#          [ 61],
#          ...,
#          [ 85],
#          [ 90],
#          [ 96]]]], shape=(7178, 48, 48, 1), dtype=uint8)

# %%
y_test
# Out:
# array([0, 0, 0, ..., 6, 6, 6], shape=(7178,))

# %%
from sklearn.utils import shuffle
X_train,y_train = shuffle(X_train,y_train,random_state=42)

# %%
X_train.shape
# Out:
# (28709, 48, 48, 1)

# %%
y_train.shape
# Out:
# (28709,)

# %%
from keras.utils import to_categorical

# %%
y_train = to_categorical(y_train,num_classes=7)

# %%
y_train.shape
# Out:
# (28709, 7, 7)

# %%
from keras import Sequential
from keras.layers import Conv2D,MaxPooling2D, Flatten, Dense

# %%
model = Sequential()
model.add(Conv2D(filters = 126,kernel_size=(3,3), activation='relu', input_shape = (48,48,1)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(units=96, activation='relu'))
model.add(Dense(units=64, activation='relu'))
model.add(Dense(units=7, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, validation_split=0.30, epochs=20)
# Out:
# Epoch 1/20
# 628/628 ━━━━━━━━━━━━━━━━━━━━ 27s 41ms/step - accuracy: 0.3083 - loss: 1.2724 - val_accuracy: 0.3642 - val_loss: 0.3693
# Epoch 2/20
# 628/628 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.4475 - loss: 0.3350 - val_accuracy: 0.3967 - val_loss: 0.3582
# Epoch 3/20
# 628/628 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.5289 - loss: 0.2958 - val_accuracy: 0.4031 - val_loss: 0.3708
# Epoch 4/20
# 628/628 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.6045 - loss: 0.2579 - val_accuracy: 0.4184 - val_loss: 0.3841
# Epoch 5/20
# 628/628 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.6674 - loss: 0.2256 - val_accuracy: 0.4123 - val_loss: 0.4286
# Epoch 6/20
# 628/628 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.7228 - loss: 0.1929 - val_accuracy: 0.4152 - val_loss: 0.4696
# Epoch 7/20
# 628/628 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.7689 - loss: 0.1658 - val_accuracy: 0.3894 - val_loss: 0.5616
# Epoch 8/20
# 628/628 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8055 - loss: 0.1475 - val_accuracy: 0.4013 - val_loss: 0.6066
# Epoch 9/20
# 628/628 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8308 - loss: 0.1304 - val_accuracy: 0.4000 - val_loss: 0.6700
# Epoch 10/20
# 628/628 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8506 - loss: 0.1205 - val_accuracy: 0.4098 - val_loss: 0.7617
# Epoch 11/20
# 628/628 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8698 - loss: 0.1076 - val_accuracy: 0.3907 - val_loss: 0.7702
# Epoch 12/20
# 628/628 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8948 - loss: 0.0915 - val_accuracy: 0.3961 - val_loss: 0.9665
# Epoch 13/20
# 628/628 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.9112 - loss: 0.0821 - val_accuracy: 0.3965 - val_loss: 0.9908
# Epoch 14/20
# 628/628 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.9201 - loss: 0.0760 - val_accuracy: 0.3917 - val_loss: 1.0934
# Epoch 15/20
# 628/628 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.9268 - loss: 0.0716 - val_accuracy: 0.3894 - val_loss: 1.1057
# Epoch 16/20
# 628/628 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.9345 - loss: 0.0676 - val_accuracy: 0.3916 - val_loss: 1.2060
# Epoch 17/20
# 628/628 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.9464 - loss: 0.0521 - val_accuracy: 0.4065 - val_loss: 1.3422
# Epoch 18/20
# 628/628 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.9501 - loss: 0.0507 - val_accuracy: 0.3961 - val_loss: 1.4213
# Epoch 19/20
# 628/628 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.9468 - loss: 0.0555 - val_accuracy: 0.3892 - val_loss: 1.4498
# Epoch 20/20
# 628/628 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.9647 - loss: 0.0405 - val_accuracy: 0.4006 - val_loss: 1.6091

# %%
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])

# %%
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (7178, 48, 48, 1)
# (7178, 7)

# %%
import numpy as np
from keras.utils import to_categorical

# вернуть к обычным классам
y_test = np.argmax(y_test, axis=-1)

# если форма всё ещё не (7178,)
while len(y_test.shape) > 1:
    y_test = np.argmax(y_test, axis=-1)

# теперь заново one-hot ОДИН раз
y_test = to_categorical(y_test, 7)

print(y_test.shape)
# Out:
# (7178, 7)

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_acc * 100:.2f}%")
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4067 - loss: 1.6426
# Test Accuracy: 40.67%
