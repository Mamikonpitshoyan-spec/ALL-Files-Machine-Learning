# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import os

# %%
os.listdir('gender_dataset/')
# Out:
# ['men', 'women']

# %%
os.listdir('gender_dataset/men/')
# Out:
# ['.ipynb_checkpoints',
#  '1.jpg',
#  '10.jpg',
#  '100.jpg',
#  '101.jpg',
#  '102.jpg',
#  '103.jpg',
#  '104.jpg',
#  '105.jpg',
#  '106.jpg',
#  '107.jpg',
#  '108.jpg',
#  '109.jpg',
#  '11.jpg',
#  '110.jpg',
#  '111.jpg',
#  '112.jpg',
#  '113.jpg',
#  '114.jpg',
#  '115.jpg',
#  '116.jpg',
#  '117.jpg',
#  '118.jpg',
#  '119.jpg',
#  '12.jpg',
#  '120.jpg',
#  '121.jpg',
#  '122.jpg',
#  '123.jpg',
#  '124.jpg',
#  '125.jpg',
#  '126.jpg',
#  '127.jpg',
#  '128.jpg',
#  '129.jpg',
#  '13.jpg',
#  '130.jpg',
#  '131.jpg',
#  '132.jpg',
#  '133.jpg',
#  '134.jpg',
#  '135.jpg',
#  '136.jpg',
#  '137.jpg',
#  '138.jpg',
#  '139.jpg',
#  '14.jpg',
#  '140.jpg',
#  '141.jpg',
#  '142.jpg',
#  '143.jpg',
#  '144.jpg',
#  '145.jpg',
#  '146.jpg',
#  '147.jpg',
#  '148.jpg',
#  '149.jpg',
#  '15.jpg',
#  '150.jpg',
#  '151.jpg',
#  '152.jpg',
#  '153.jpg',
#  '154.jpg',
#  '155.jpg',
#  '156.jpg',
#  '157.jpg',
#  '158.jpg',
#  '159.jpg',
#  '16.jpg',
#  '160.jpg',
#  '161.jpg',
# ...

# %%
os.listdir('gender_dataset/women/')
# Out:
# ['1.jpg',
#  '10.jpg',
#  '100.jpg',
#  '101.jpg',
#  '102.jpg',
#  '103.jpg',
#  '104.jpg',
#  '105.jpg',
#  '106.jpg',
#  '107.jpg',
#  '108.jpg',
#  '109.jpg',
#  '11.jpg',
#  '110.jpg',
#  '111.jpg',
#  '112.jpg',
#  '113.jpg',
#  '114.jpg',
#  '115.jpg',
#  '116.jpg',
#  '117.jpg',
#  '118.jpg',
#  '119.jpg',
#  '12.jpg',
#  '120.jpg',
#  '121.jpg',
#  '122.jpg',
#  '123.jpg',
#  '124.jpg',
#  '125.jpg',
#  '126.jpg',
#  '127.jpg',
#  '128.jpg',
#  '129.jpg',
#  '13.jpg',
#  '130.jpg',
#  '131.jpg',
#  '132.jpg',
#  '133.jpg',
#  '134.jpg',
#  '135.jpg',
#  '136.jpg',
#  '137.jpg',
#  '138.jpg',
#  '139.jpg',
#  '14.jpg',
#  '140.jpg',
#  '141.jpg',
#  '142.jpg',
#  '143.jpg',
#  '144.jpg',
#  '145.jpg',
#  '146.jpg',
#  '147.jpg',
#  '148.jpg',
#  '149.jpg',
#  '15.jpg',
#  '150.jpg',
#  '151.jpg',
#  '152.jpg',
#  '153.jpg',
#  '154.jpg',
#  '155.jpg',
#  '156.jpg',
#  '157.jpg',
#  '158.jpg',
#  '159.jpg',
#  '16.jpg',
#  '160.jpg',
#  '161.jpg',
#  '162.jpg',
#  '163.jpg',
# ...

# %%
temp_image = mpimg.imread('gender_dataset/men/10.jpg')

# %%
temp_image.shape
# Out:
# (530, 910, 3)

# %%
plt.imshow(temp_image)

# %%
temp_image = mpimg.imread('gender_dataset/women/10.jpg')

# %%
temp_image.shape
# Out:
# (720, 1280, 3)

# %%
plt.imshow(temp_image)

# %%
data = {
    'men':0,
    'women':1
}

# %%
X_train = []
y_train = []
for i in os.listdir('gender_dataset/'):
    for j in os.listdir(f'gender_dataset/{i}/'):
        try:
            image = mpimg.imread(f'gender_dataset/{i}/{j}')
            image = cv2.resize(image, (300, 300))
            image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            image = image.reshape(300, 300, 1)
            X_train.append(image)
            y_train.append(data[i])
        except:
            continue
        
X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
X_train
# Out:
# array([[[[227.        ],
#          [227.        ],
#          [227.        ],
#          ...,
#          [221.        ],
#          [221.        ],
#          [221.        ]],
#
#         [[227.        ],
#          [227.        ],
#          [227.        ],
#          ...,
#          [221.        ],
#          [221.        ],
#          [221.        ]],
#
#         [[227.        ],
#          [227.        ],
#          [227.        ],
#          ...,
#          [221.        ],
#          [221.        ],
#          [221.        ]],
#
#         ...,
#
#         [[227.        ],
#          [227.        ],
#          [227.        ],
#          ...,
#          [234.        ],
#          [234.        ],
#          [234.        ]],
#
#         [[227.        ],
#          [227.        ],
#          [228.        ],
#          ...,
#          [235.        ],
#          [235.        ],
#          [235.        ]],
#
#         [[227.        ],
#          [227.        ],
# ...

# %%
y_train
# Out:
# array([0, 0, 0, ..., 1, 1, 1], shape=(1668,))

# %%
from sklearn.utils import shuffle
X_train,y_train = shuffle(X_train,y_train,random_state=42)

# %%
X_train.shape
# Out:
# (1668, 300, 300, 1)

# %%
y_train.shape
# Out:
# (1668,)

# %%
from keras.utils import to_categorical

# %%
y_train = to_categorical(y_train,num_classes=2)

# %%
y_train.shape
# Out:
# (1668, 2)

# %%
from keras import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %%
model = Sequential()

model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu', input_shape=(300, 300, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())

model.add(Dense(units=32, activation='relu'))
model.add(Dense(units=16, activation='relu'))
model.add(Dense(units=2, activation='softmax'))
# Out:
# C:\Users\USER\Desktop\ML jupyter\venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, validation_split=0.15, epochs=20)
# Out:
# Epoch 1/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 37s 771ms/step - accuracy: 0.5328 - loss: 172.0249 - val_accuracy: 0.5657 - val_loss: 6.6085
# Epoch 2/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 34s 744ms/step - accuracy: 0.7445 - loss: 2.6407 - val_accuracy: 0.5737 - val_loss: 3.3507
# Epoch 3/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 34s 744ms/step - accuracy: 0.9195 - loss: 0.2736 - val_accuracy: 0.5618 - val_loss: 2.8257
# Epoch 4/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 34s 745ms/step - accuracy: 0.9711 - loss: 0.0746 - val_accuracy: 0.5936 - val_loss: 2.7873
# Epoch 5/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 42s 757ms/step - accuracy: 0.9788 - loss: 0.0502 - val_accuracy: 0.5896 - val_loss: 2.7785
# Epoch 6/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 40s 734ms/step - accuracy: 0.9859 - loss: 0.0445 - val_accuracy: 0.5896 - val_loss: 2.7882
# Epoch 7/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 33s 730ms/step - accuracy: 0.9802 - loss: 0.0470 - val_accuracy: 0.5857 - val_loss: 3.2666
# Epoch 8/20
# ...

# %%
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])

# %%
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])

# %%
test_image = mpimg.imread('images.jpg')

# %%
plt.imshow(test_image)

# %%
test_image.shape
# Out:
# (183, 275, 3)

# %%
test_image = cv2.resize(test_image, (300, 300))
test_image = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)
test_image = test_image.reshape(1, 300, 300, 1)

# %%
np.argmax(model.predict(test_image))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# np.int64(1)

# %%
test_image = mpimg.imread('Outdoors-man-portrait_(cropped).jpg')

# %%
plt.imshow(test_image)

# %%
test_image.shape
# Out:
# (624, 500, 3)

# %%
test_image = cv2.resize(test_image, (300, 300))
test_image = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)
test_image = test_image.reshape(1, 300, 300, 1)

# %%
np.argmax(model.predict(test_image))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# np.int64(0)
