# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import os

# %%
os.listdir('Training/Training/')
# Out:
# ['.ipynb_checkpoints', 'not_smoking', 'smoking']

# %%
temp_image = mpimg.imread('Training/Training/notsmoking_0001.jpg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 temp_image = mpimg.imread('Training/Training/notsmoking_0001.jpg')
#
# File ~\Desktop\ML jupyter\venv\Lib\site-packages\matplotlib\image.py:1520, in imread(fname, format)
#    1513 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1514     # Pillow doesn't handle URLs directly.
#    1515     raise ValueError(
#    1516         "Please open the URL for reading and pass the "
#    1517         "result to Pillow, e.g. with "
#    1518         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1519         )
# -> 1520 with img_open(fname) as image:
#    1521     return (_pil_png_to_float_array(image)
#    1522             if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#    1523             pil_to_array(image))
#
# File ~\Desktop\ML jupyter\venv\Lib\site-packages\PIL\Image.py:3493, in open(fp, mode, formats)
#    3491 if is_path(fp):
#    3492     filename = os.fspath(fp)
# -> 3493     fp = builtins.open(filename, "rb")
#    3494     exclusive_fp = True
#    3495 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Training/Training/notsmoking_0001.jpg'

# %%
temp_image.shape
# Out:
# (250, 250, 3)

# %%
os.listdir('Validation/')
# Out:
# ['Validation']

# %%
temp_image = mpimg.imread('Validation/Validation/notsmoking_0006.jpg')

# %%
temp_image.shape
# Out:
# (250, 250, 3)

# %%
plt.imshow(temp_image)

# %%
import os
import shutil

base_path = 'Training/Training'

smoking_dir = os.path.join(base_path, 'smoking')
notsmoking_dir = os.path.join(base_path, 'not_smoking')

os.makedirs(smoking_dir, exist_ok=True)
os.makedirs(notsmoking_dir, exist_ok=True)

for file in os.listdir(base_path):

    file_path = os.path.join(base_path, file)

    if os.path.isdir(file_path):
        continue

    filename_lower = file.lower()

    if filename_lower.startswith('smoking_'):
        shutil.move(file_path, os.path.join(smoking_dir, file))

    elif filename_lower.startswith('notsmoking_'):
        shutil.move(file_path, os.path.join(notsmoking_dir, file))

print("Готово ✅")
# Out:
# Готово ✅

# %%
import os
import shutil

base_path = 'Validation/Validation/'

smoking_dir = os.path.join(base_path, 'smoking')
notsmoking_dir = os.path.join(base_path, 'not_smoking')

os.makedirs(smoking_dir, exist_ok=True)
os.makedirs(notsmoking_dir, exist_ok=True)

for file in os.listdir(base_path):

    file_path = os.path.join(base_path, file)

    if os.path.isdir(file_path):
        continue

    filename_lower = file.lower()

    if filename_lower.startswith('smoking_'):
        shutil.move(file_path, os.path.join(smoking_dir, file))

    elif filename_lower.startswith('notsmoking_'):
        shutil.move(file_path, os.path.join(notsmoking_dir, file))

print("Готово ✅")
# Out:
# Готово ✅

# %%
import os
import shutil

base_path = 'Testing/Testing/'

smoking_dir = os.path.join(base_path, 'smoking')
notsmoking_dir = os.path.join(base_path, 'not_smoking')

os.makedirs(smoking_dir, exist_ok=True)
os.makedirs(notsmoking_dir, exist_ok=True)

for file in os.listdir(base_path):

    file_path = os.path.join(base_path, file)

    if os.path.isdir(file_path):
        continue

    filename_lower = file.lower()

    if filename_lower.startswith('smoking_'):
        shutil.move(file_path, os.path.join(smoking_dir, file))

    elif filename_lower.startswith('notsmoking_'):
        shutil.move(file_path, os.path.join(notsmoking_dir, file))

print("Готово ✅")

# %%
X_train = []
y_train = []
base_path = 'Training/Training'
data = {'not_smoking':0, 'smoking':1}
for i in os.listdir(base_path):
    if i.startswith('.'):
        continue
    for j in os.listdir(f'{base_path}/{i}/'):
        try:
            image = mpimg.imread(f'{base_path}/{i}/{j}')
            image = cv2.resize(image, (250,250))
            image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            image = image.reshape(250,250,1)
            X_train.append(image)
            y_train.append(data[i])
        except:
             continue
X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
X_test = []
y_test = []
base_path = 'Validation/Validation/'
data = {'not_smoking':0, 'smoking':1}
for i in os.listdir(base_path):
    if i.startswith('.'):
        continue
    for j in os.listdir(f'{base_path}/{i}/'):
        try:
            image = mpimg.imread(f'{base_path}/{i}/{j}')
            
            image = cv2.resize(image, (250,250))
            image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            image = image.reshape(250,250,1)
            X_test.append(image)
            y_test.append(data[i])
        except:
             continue
X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
X_train.shape
# Out:
# (716, 250, 250, 1)

# %%
X_test.shape
# Out:
# (180, 250, 250, 1)

# %%
X_train
# Out:
# array([[[[0.7372549 ],
#          [0.73333333],
#          [0.7254902 ],
#          ...,
#          [0.55294118],
#          [0.55686275],
#          [0.54901961]],
#
#         [[0.74117647],
#          [0.74117647],
#          [0.7372549 ],
#          ...,
#          [0.55686275],
#          [0.55686275],
#          [0.55686275]],
#
#         [[0.75294118],
#          [0.74901961],
#          [0.74509804],
#          ...,
#          [0.56078431],
#          [0.56078431],
#          [0.56862745]],
#
#         ...,
#
#         [[0.42352941],
#          [0.49019608],
#          [0.5254902 ],
#          ...,
#          [0.65882353],
#          [0.65882353],
#          [0.65490196]],
#
#         [[0.4       ],
#          [0.4745098 ],
#          [0.51372549],
#          ...,
#          [0.6627451 ],
#          [0.6627451 ],
#          [0.65882353]],
#
#         [[0.39607843],
#          [0.45882353],
#          [0.51764706],
#          ...,
#          [0.6627451 ],
#          [0.65882353],
#          [0.6627451 ]]],
#
#
#        [[[0.28235294],
#          [0.2745098 ],
#          [0.24705882],
#          ...,
#          [0.33333333],
#          [0.36862745],
#          [0.35686275]],
#
#         [[0.2745098 ],
#          [0.23921569],
#          [0.22745098],
#          ...,
#          [0.32941176],
#          [0.34117647],
#          [0.32941176]],
#
#         [[0.2627451 ],
#          [0.22745098],
#          [0.21568627],
#          ...,
#          [0.3372549 ],
#          [0.33333333],
#          [0.31764706]],
#
#         ...,
#
#         [[0.12156863],
#          [0.10196078],
#          [0.11372549],
#          ...,
#          [0.70196078],
#          [0.70588235],
#          [0.70980392]],
#
#         [[0.11372549],
#          [0.10196078],
#          [0.10980392],
#          ...,
#          [0.70196078],
#          [0.71372549],
#          [0.71764706]],
#
#         [[0.09411765],
#          [0.09019608],
#          [0.09803922],
#          ...,
#          [0.70588235],
#          [0.7254902 ],
#          [0.73333333]]],
#
#
#        [[[0.30196078],
#          [0.37254902],
#          [0.38039216],
#          ...,
#          [0.26666667],
#          [0.2627451 ],
#          [0.27058824]],
#
#         [[0.34901961],
#          [0.40784314],
#          [0.34117647],
#          ...,
#          [0.2627451 ],
#          [0.2627451 ],
#          [0.27843137]],
#
#         [[0.41176471],
#          [0.37647059],
#          [0.31372549],
#          ...,
#          [0.25882353],
#          [0.26666667],
#          [0.28235294]],
#
#         ...,
#
#         [[0.48627451],
#          [0.48235294],
#          [0.29803922],
#          ...,
#          [0.31372549],
#          [0.23137255],
#          [0.23921569]],
#
#         [[0.52156863],
#          [0.41176471],
#          [0.20784314],
#          ...,
#          [0.32156863],
#          [0.26666667],
#          [0.24705882]],
#
#         [[0.48235294],
#          [0.3254902 ],
#          [0.15294118],
#          ...,
#          [0.30588235],
#          [0.26666667],
#          [0.24705882]]],
#
#
#        ...,
#
#
#        [[[0.01960784],
#          [0.01568627],
#          [0.02352941],
#          ...,
#          [0.04705882],
#          [0.03921569],
#          [0.03921569]],
#
#         [[0.01960784],
#          [0.01960784],
#          [0.01960784],
#          ...,
#          [0.02745098],
#          [0.03921569],
#          [0.05098039]],
#
#         [[0.01176471],
#          [0.01176471],
#          [0.01960784],
#          ...,
#          [0.04705882],
#          [0.05882353],
#          [0.04705882]],
#
#         ...,
#
#         [[0.01176471],
#          [0.01176471],
#          [0.01176471],
#          ...,
#          [0.36470588],
#          [0.36862745],
#          [0.36862745]],
#
#         [[0.01176471],
#          [0.01176471],
#          [0.01176471],
#          ...,
#          [0.36078431],
#          [0.36470588],
#          [0.36470588]],
#
#         [[0.01176471],
#          [0.01176471],
#          [0.01176471],
#          ...,
#          [0.35686275],
#          [0.36078431],
#          [0.36078431]]],
#
#
#        [[[0.67058824],
#          [0.67843137],
#          [0.67058824],
#          ...,
#          [0.67843137],
#          [0.67058824],
#          [0.6745098 ]],
#
#         [[0.65098039],
#          [0.65490196],
#          [0.65098039],
#          ...,
#          [0.69019608],
#          [0.68627451],
#          [0.68235294]],
#
#         [[0.62352941],
#          [0.62352941],
#          [0.61960784],
#          ...,
#          [0.69411765],
#          [0.69019608],
#          [0.69019608]],
#
#         ...,
#
#         [[0.98039216],
#          [0.97254902],
#          [0.96862745],
#          ...,
#          [0.10980392],
#          [0.11764706],
#          [0.2       ]],
#
#         [[0.98039216],
#          [0.98039216],
#          [0.99215686],
#          ...,
#          [0.2       ],
#          [0.16470588],
#          [0.21568627]],
#
#         [[0.70980392],
#          [0.78431373],
#          [0.85490196],
#          ...,
#          [0.20392157],
#          [0.19607843],
#          [0.24705882]]],
#
#
#        [[[0.77254902],
#          [0.77254902],
#          [0.76862745],
#          ...,
#          [0.76470588],
#          [0.76470588],
#          [0.76078431]],
#
#         [[0.77647059],
#          [0.77254902],
#          [0.76862745],
#          ...,
#          [0.76470588],
#          [0.76470588],
#          [0.76470588]],
#
#         [[0.77254902],
#          [0.77254902],
#          [0.76862745],
#          ...,
#          [0.76862745],
#          [0.76470588],
#          [0.76862745]],
#
#         ...,
#
#         [[0.24313725],
#          [0.24705882],
#          [0.24705882],
#          ...,
#          [0.73333333],
#          [0.74117647],
#          [0.76078431]],
#
#         [[0.24313725],
#          [0.23529412],
#          [0.23921569],
#          ...,
#          [0.79215686],
#          [0.82352941],
#          [0.84313725]],
#
#         [[0.24705882],
#          [0.23529412],
#          [0.22745098],
#          ...,
#          [0.86666667],
#          [0.88235294],
#          [0.88627451]]]], shape=(716, 250, 250, 1))

# %%
X_test
# Out:
# array([[[[0.02745098],
#          [0.02745098],
#          [0.03529412],
#          ...,
#          [0.27058824],
#          [0.28235294],
#          [0.29411765]],
#
#         [[0.03137255],
#          [0.03137255],
#          [0.03921569],
#          ...,
#          [0.2745098 ],
#          [0.28235294],
#          [0.28627451]],
#
#         [[0.03921569],
#          [0.03921569],
#          [0.03921569],
#          ...,
#          [0.2627451 ],
#          [0.27058824],
#          [0.26666667]],
#
#         ...,
#
#         [[0.04313725],
#          [0.03921569],
#          [0.04313725],
#          ...,
#          [0.03921569],
#          [0.03137255],
#          [0.03137255]],
#
#         [[0.03921569],
#          [0.03921569],
#          [0.04313725],
#          ...,
#          [0.05882353],
#          [0.05098039],
#          [0.03921569]],
#
#         [[0.04313725],
#          [0.04313725],
#          [0.04705882],
#          ...,
#          [0.08235294],
#          [0.0745098 ],
#          [0.0627451 ]]],
#
#
#        [[[0.12156863],
#          [0.12156863],
#          [0.1254902 ],
#          ...,
#          [0.14117647],
#          [0.1372549 ],
#          [0.13333333]],
#
#         [[0.1254902 ],
#          [0.12941176],
#          [0.1254902 ],
#          ...,
#          [0.14117647],
#          [0.13333333],
#          [0.13333333]],
#
#         [[0.1254902 ],
#          [0.12941176],
#          [0.12156863],
#          ...,
#          [0.14117647],
#          [0.1372549 ],
#          [0.1372549 ]],
#
#         ...,
#
#         [[0.10588235],
#          [0.09411765],
#          [0.10980392],
#          ...,
#          [0.14509804],
#          [0.1254902 ],
#          [0.10588235]],
#
#         [[0.10588235],
#          [0.10196078],
#          [0.12941176],
#          ...,
#          [0.14509804],
#          [0.1254902 ],
#          [0.10980392]],
#
#         [[0.10588235],
#          [0.11764706],
#          [0.14901961],
#          ...,
#          [0.14117647],
#          [0.12156863],
#          [0.10588235]]],
#
#
#        [[[0.74117647],
#          [0.74509804],
#          [0.74117647],
#          ...,
#          [0.8       ],
#          [0.8       ],
#          [0.80392157]],
#
#         [[0.74901961],
#          [0.74509804],
#          [0.74509804],
#          ...,
#          [0.80784314],
#          [0.80392157],
#          [0.81176471]],
#
#         [[0.75686275],
#          [0.74509804],
#          [0.74117647],
#          ...,
#          [0.80392157],
#          [0.80392157],
#          [0.80784314]],
#
#         ...,
#
#         [[0.57254902],
#          [0.57647059],
#          [0.57647059],
#          ...,
#          [0.2627451 ],
#          [0.27058824],
#          [0.2627451 ]],
#
#         [[0.57254902],
#          [0.57647059],
#          [0.58039216],
#          ...,
#          [0.23529412],
#          [0.23921569],
#          [0.23921569]],
#
#         [[0.56862745],
#          [0.57254902],
#          [0.57254902],
#          ...,
#          [0.21568627],
#          [0.22745098],
#          [0.24705882]]],
#
#
#        ...,
#
#
#        [[[0.18039216],
#          [0.18039216],
#          [0.17647059],
#          ...,
#          [0.03921569],
#          [0.04705882],
#          [0.06666667]],
#
#         [[0.17254902],
#          [0.16862745],
#          [0.16470588],
#          ...,
#          [0.03529412],
#          [0.04313725],
#          [0.05882353]],
#
#         [[0.16078431],
#          [0.15686275],
#          [0.15686275],
#          ...,
#          [0.05882353],
#          [0.04313725],
#          [0.04313725]],
#
#         ...,
#
#         [[0.11372549],
#          [0.10980392],
#          [0.10980392],
#          ...,
#          [0.52156863],
#          [0.51372549],
#          [0.50588235]],
#
#         [[0.11764706],
#          [0.11372549],
#          [0.11372549],
#          ...,
#          [0.52156863],
#          [0.51372549],
#          [0.50588235]],
#
#         [[0.11764706],
#          [0.11764706],
#          [0.11372549],
#          ...,
#          [0.52156863],
#          [0.51372549],
#          [0.50588235]]],
#
#
#        [[[0.58823529],
#          [0.58039216],
#          [0.56862745],
#          ...,
#          [0.16078431],
#          [0.16470588],
#          [0.17254902]],
#
#         [[0.56470588],
#          [0.57254902],
#          [0.57647059],
#          ...,
#          [0.16470588],
#          [0.16470588],
#          [0.17254902]],
#
#         [[0.55686275],
#          [0.57254902],
#          [0.58431373],
#          ...,
#          [0.16470588],
#          [0.16470588],
#          [0.16862745]],
#
#         ...,
#
#         [[0.16470588],
#          [0.18039216],
#          [0.19607843],
#          ...,
#          [0.11764706],
#          [0.11764706],
#          [0.11764706]],
#
#         [[0.16470588],
#          [0.18431373],
#          [0.2       ],
#          ...,
#          [0.12156863],
#          [0.12156863],
#          [0.1254902 ]],
#
#         [[0.17254902],
#          [0.18431373],
#          [0.19607843],
#          ...,
#          [0.12156863],
#          [0.1254902 ],
#          [0.12156863]]],
#
#
#        [[[0.01568627],
#          [0.01960784],
#          [0.01960784],
#          ...,
#          [0.70196078],
#          [0.69803922],
#          [0.70196078]],
#
#         [[0.01960784],
#          [0.02352941],
#          [0.01960784],
#          ...,
#          [0.70196078],
#          [0.70980392],
#          [0.70980392]],
#
#         [[0.01176471],
#          [0.01960784],
#          [0.01960784],
#          ...,
#          [0.70588235],
#          [0.70980392],
#          [0.70980392]],
#
#         ...,
#
#         [[0.05098039],
#          [0.05490196],
#          [0.0627451 ],
#          ...,
#          [0.09019608],
#          [0.09019608],
#          [0.08627451]],
#
#         [[0.05490196],
#          [0.05490196],
#          [0.05490196],
#          ...,
#          [0.07843137],
#          [0.07843137],
#          [0.09019608]],
#
#         [[0.05490196],
#          [0.04705882],
#          [0.05882353],
#          ...,
#          [0.0627451 ],
#          [0.0627451 ],
#          [0.08235294]]]], shape=(180, 250, 250, 1))

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
from keras.utils import to_categorical

# %%
y_train = to_categorical(y_train,num_classes=2)
y_test = to_categorical(y_test,num_classes=2)

# %%
from keras import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.optimizers import Adam

# %%
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same', input_shape=(250, 250, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(filters=32, kernel_size=(3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(units=32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=16, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(units=2, activation='softmax'))

# %%
model.compile(optimizer = Adam(learning_rate=0.001),loss = 'binary_crossentropy',metrics = ['accuracy'])

# %%
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs = 20, batch_size = 32)
# Out:
# Epoch 1/20
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs = 20, batch_size = 32)
#
# File ~\Desktop\ML jupyter\venv\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\Desktop\ML jupyter\venv\Lib\site-packages\keras\src\backend\tensorflow\nn.py:1273, in binary_crossentropy(target, output, from_logits)
#    1270 output = tf.convert_to_tensor(output)
#    1272 if len(target.shape) != len(output.shape):
# -> 1273     raise ValueError(
#    1274         "Arguments `target` and `output` must have the same rank "
#    1275         "(ndim). Received: "
#    1276         f"target.shape={target.shape}, output.shape={output.shape}"
#    1277     )
#    1278 for e1, e2 in zip(target.shape, output.shape):
#    1279     if e1 is not None and e2 is not None and e1 != e2:
#
# ValueError: Arguments `target` and `output` must have the same rank (ndim). Received: target.shape=(None, 2, 2), output.shape=(None, 2)

# %%
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])

# %%
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_acc * 100:.2f}%")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.7167 - loss: 0.7821
# Test Accuracy: 71.67%
