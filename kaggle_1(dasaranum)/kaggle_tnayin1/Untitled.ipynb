# %%
# mi axyusaki miji int eri u xary tesakneri berumy str
# df_train['Condition2'] = df_train['Condition2'].astype(str)
# df_test['Condition2']  = df_test['Condition2'].astype(str)
# Nonery anteselu hamar
df_train['Exterior2nd'] = df_train['Exterior2nd'].fillna('None')
# df_test['Exterior2nd']  = df_test['Exterior2nd'].fillna('None')#

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df_train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df_test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = LabelEncoder()

# %%
print(df_train['MSZoning'].isna().sum())
print(df_test['MSZoning'].isna().sum())
# Out:
# 0
# 4

# %%
df_train['MSZoning'] = df_train['MSZoning'].fillna('None')
df_test['MSZoning']  = df_test['MSZoning'].fillna('None')

# %%
all_values = pd.concat([
    df_train['MSZoning'],
    df_test['MSZoning']
])

label.fit(all_values)
# Out:
# LabelEncoder()

# %%
df_train['MSZoning'] = label.transform(df_train['MSZoning'])
df_test['MSZoning'] = label.transform(df_test['MSZoning'])

# %%
print(df_train['MSZoning'].dtype)
print(df_test['MSZoning'].dtype)

print(df_train['MSZoning'].unique())
print(df_test['MSZoning'].unique())
# Out:
# int64
# int64
# [4 5 0 1 3]
# [3 4 5 1 0 2]

# %%
df_train
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60         4         65.0     8450   Pave   NaN      Reg
# 1        2          20         4         80.0     9600   Pave   NaN      Reg
# 2        3          60         4         68.0    11250   Pave   NaN      IR1
# 3        4          70         4         60.0     9550   Pave   NaN      IR1
# 4        5          60         4         84.0    14260   Pave   NaN      IR1
# ...    ...         ...       ...          ...      ...    ...   ...      ...
# 1455  1456          60         4         62.0     7917   Pave   NaN      Reg
# 1456  1457          20         4         85.0    13175   Pave   NaN      Reg
# 1457  1458          70         4         66.0     9042   Pave   NaN      Reg
# 1458  1459          20         4         68.0     9717   Pave   NaN      Reg
# 1459  1460          20         4         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df_test
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20         3         80.0    11622   Pave   NaN      Reg
# 1     1462          20         4         81.0    14267   Pave   NaN      IR1
# 2     1463          60         4         74.0    13830   Pave   NaN      IR1
# 3     1464          60         4         78.0     9978   Pave   NaN      IR1
# 4     1465         120         4         43.0     5005   Pave   NaN      IR1
# ...    ...         ...       ...          ...      ...    ...   ...      ...
# 1454  2915         160         5         21.0     1936   Pave   NaN      Reg
# 1455  2916         160         5         21.0     1894   Pave   NaN      Reg
# 1456  2917          20         4        160.0    20000   Pave   NaN      Reg
# 1457  2918          85         4         62.0    10441   Pave   NaN      Reg
# 1458  2919          60         4         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
Age
# Out:
# set()

# %%
set(df_train['Street']).difference(set(df_test['Street']))
# Out:
# set()

# %%
df_train['Street'] = df_train['Street'].fillna('None')
df_test['Street']  = df_test['Street'].fillna('None')

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
all_vals = pd.concat([
    df_train['Street'],
    df_test['Street']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['Street'] = label.transform(df_train['Street'])
df_test['Street'] = label.transform(df_test['Street'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['Alley']).difference(set(df_train['Alley']))
# Out:
# set()

# %%
df_train['Alley'] = df_train['Alley'].fillna('None')
df_test['Alley']  = df_test['Alley'].fillna('None')

# %%
all_vals = pd.concat([
    df_train['Alley'],
    df_test['Alley']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['Alley'] = label.transform(df_train['Alley'])
df_test['Alley'] = label.transform(df_test['Alley'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['LotShape']).difference(set(df_train['LotShape']))
# Out:
# set()

# %%
df_train['LotShape'] = df_train['LotShape'].fillna('None')
df_test['LotShape']  = df_test['LotShape'].fillna('None')

# %%
all_vals = pd.concat([
    df_train['LotShape'],
    df_test['LotShape']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['LotShape'] = label.transform(df_train['LotShape'])
df_test['LotShape'] = label.transform(df_test['LotShape'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['LandContour']).difference(set(df_train['LandContour']))
# Out:
# set()

# %%
df_train['LandContour'] = df_train['LandContour'].astype(str)
df_test['LandContour']  = df_test['LandContour'].astype(str)

# %%
all_vals = pd.concat([
    df_train['LandContour'],
    df_test['LandContour']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['LandContour'] = label.transform(df_train['LandContour'])
df_test['LandContour']  = label.transform(df_test['LandContour'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['Utilities']).difference(set(df_train['Utilities']))
# Out:
# {nan}

# %%
df_train['Utilities'] = df_train['Utilities'].fillna('None')
df_test['Utilities']  = df_test['Utilities'].fillna('None')

# %%
all_vals = pd.concat([
    df_train['Utilities'],
    df_test['Utilities']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['Utilities'] = label.transform(df_train['Utilities'])
df_test['Utilities']  = label.transform(df_test['Utilities'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['LotConfig']).difference(set(df_train['LotConfig']))
# Out:
# set()

# %%
all_vals = pd.concat([
    df_train['LotConfig'],
    df_test['LotConfig']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['LotConfig'] = label.transform(df_train['LotConfig'])
df_test['LotConfig']  = label.transform(df_test['LotConfig'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['LandSlope']).difference(set(df_train['LandSlope']))
# Out:
# set()

# %%
all_vals = pd.concat([
    df_train['LandSlope'],
    df_test['LandSlope']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['LandSlope'] = label.transform(df_train['LandSlope'])
df_test['LandSlope']  = label.transform(df_test['LandSlope'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['Neighborhood']).difference(set(df_train['Neighborhood']))
# Out:
# set()

# %%
all_vals = pd.concat([
    df_train['Neighborhood'],
    df_test['Neighborhood']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['Neighborhood'] = label.fit_transform(df_train['Neighborhood'])
df_test['Neighborhood'] = label.transform(df_test['Neighborhood'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['Condition1']).difference(df_train['Condition1'])
# Out:
# set()

# %%
all_vals = pd.concat([
    df_train['Condition1'],
    df_train['Condition1'],
   
])
label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['Condition1'] = label.fit_transform(df_train['Condition1'])
df_test['Condition1'] = label.transform(df_test['Condition1'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['Condition2']).difference(set(df_train['Condition2']))
# Out:
# set()

# %%
df_train['Condition2'].apply(type).value_counts()
df_test['Condition2'].apply(type).value_counts()
# Out:
# Condition2
# <class 'str'>    1459
# Name: count, dtype: int64

# %%
df_train['Condition2'] = df_train['Condition2'].astype(str)
df_test['Condition2']  = df_test['Condition2'].astype(str)

# %%
df_train['Condition2'] = df_train['Condition2'].fillna('None')
df_test['Condition2']  = df_test['Condition2'].fillna('None')

# %%
all_vals = pd.concat([
    df_train['Condition2'],
    df_test['Condition2']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['Condition2'] = label.transform(df_train['Condition2'])
df_test['Condition2']  = label.transform(df_test['Condition2'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['BldgType']).difference(set(df_train['BldgType']))
# Out:
# set()

# %%
all_vals = pd.concat([
    df_train['BldgType'],
    df_test['BldgType']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['BldgType'] = label.transform(df_train['BldgType'])
df_test['BldgType']  = label.transform(df_test['BldgType'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['HouseStyle']).difference(set(df_train['HouseStyle']))
# Out:
# set()

# %%
all_vals = pd.concat([
    df_train['HouseStyle'],
    df_test['HouseStyle']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['HouseStyle'] = label.transform(df_train['HouseStyle'])
df_test['HouseStyle']  = label.transform(df_test['HouseStyle'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['RoofStyle']).difference(set(df_train['RoofStyle']))
# Out:
# set()

# %%
all_vals = pd.concat([
    df_train['RoofStyle'],
    df_test['RoofStyle']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['RoofStyle'] = label.transform(df_train['RoofStyle'])
df_test['RoofStyle']  = label.transform(df_test['RoofStyle'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['RoofMatl']).difference(set(df_train['RoofMatl']))
# Out:
# set()

# %%
all_vals = pd.concat([
    df_train['RoofMatl'],
    df_test['RoofMatl']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['RoofMatl'] = label.transform(df_train['RoofMatl'])
df_test['RoofMatl']  = label.transform(df_test['RoofMatl'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['Exterior1st']).difference(set(df_train['Exterior1st']))
# Out:
# {nan}

# %%
df_train['Exterior1st'] = df_train['Exterior1st'].fillna('None')
df_test['Exterior1st']  = df_test['Exterior1st'].fillna('None')

# %%
all_vals = pd.concat([
    df_train['Exterior1st'],
    df_test['Exterior1st']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['Exterior1st'] = label.transform(df_train['Exterior1st'])
df_test['Exterior1st']  = label.transform(df_test['Exterior1st'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['Exterior2nd']).difference(set(df_train['Exterior2nd']))
# Out:
# {nan}

# %%
df_train['Exterior2nd'] = df_train['Exterior2nd'].fillna('None')
df_test['Exterior2nd']  = df_test['Exterior2nd'].fillna('None')

# %%
all_vals = pd.concat([
    df_train['Exterior2nd'],
    df_test['Exterior2nd']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['Exterior2nd'] = label.transform(df_train['Exterior2nd'])
df_test['Exterior2nd']  = label.transform(df_test['Exterior2nd'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['MasVnrType']).difference(set(df_train['MasVnrType']))
# Out:
# set()

# %%
all_vals = pd.concat([
    df_train['MasVnrType'],
    df_test['MasVnrType']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['MasVnrType'] = label.transform(df_train['MasVnrType'])
df_test['MasVnrType']  = label.transform(df_test['MasVnrType'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['ExterQual']).difference(set(df_train['ExterQual']))
# Out:
# set()

# %%
all_vals = pd.concat([
    df_train['ExterQual'],
    df_test['ExterQual']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['ExterQual'] = label.transform(df_train['ExterQual'])
df_test['ExterQual']  = label.transform(df_test['ExterQual'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['ExterCond']).difference(set(df_train['ExterCond']))
# Out:
# set()

# %%
all_vals = pd.concat([
    df_train['ExterCond'],
    df_test['ExterCond']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['ExterCond'] = label.transform(df_train['ExterCond'])
df_test['ExterCond']  = label.transform(df_test['ExterCond'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['Foundation']).difference(set(df_train['Foundation']))
# Out:
# set()

# %%
all_vals = pd.concat([
    df_train['Foundation'],
    df_test['Foundation']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['Foundation'] = label.transform(df_train['Foundation'])
df_test['Foundation']  = label.transform(df_test['Foundation'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['BsmtQual']).difference(set(df_train['BsmtQual']))
# Out:
# set()

# %%
all_vals = pd.concat([
    df_train['BsmtQual'],
    df_test['BsmtQual']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['BsmtQual'] = label.transform(df_train['BsmtQual'])
df_test['BsmtQual']  = label.transform(df_test['BsmtQual'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['BsmtCond']).difference(set(df_train['BsmtCond']))
# Out:
# set()

# %%
all_vals = pd.concat([
    df_train['BsmtCond'],
    df_test['BsmtCond']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['BsmtCond'] = label.transform(df_train['BsmtCond'])
df_test['BsmtCond']  = label.transform(df_test['BsmtCond'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['BsmtExposure']).difference(set(df_train['BsmtExposure']))
# Out:
# set()

# %%
all_vals = pd.concat([
    df_train['BsmtExposure'],
    df_test['BsmtExposure']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['BsmtExposure'] = label.transform(df_train['BsmtExposure'])
df_test['BsmtExposure']  = label.transform(df_test['BsmtExposure'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['BsmtFinType1']).difference(set(df_train['BsmtFinType1']))
# Out:
# set()

# %%
all_vals = pd.concat([
    df_train['BsmtFinType1'],
    df_test['BsmtFinType1']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['BsmtFinType1'] = label.transform(df_train['BsmtFinType1'])
df_test['BsmtFinType1']  = label.transform(df_test['BsmtFinType1'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['BsmtFinType2']).difference(set(df_train['BsmtFinType2']))
# Out:
# set()

# %%
all_vals = pd.concat([
    df_train['BsmtFinType2'],
    df_test['BsmtFinType2']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['BsmtFinType2'] = label.transform(df_train['BsmtFinType2'])
df_test['BsmtFinType2']  = label.transform(df_test['BsmtFinType2'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['Heating']).difference(set(df_train['Heating']))
# Out:
# set()

# %%
all_vals = pd.concat([
    df_train['Heating'],
    df_test['Heating']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['Heating'] = label.transform(df_train['Heating'])
df_test['Heating']  = label.transform(df_test['Heating'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['HeatingQC']).difference(set(df_train['HeatingQC']))
# Out:
# set()

# %%
all_vals = pd.concat([
    df_train['HeatingQC'],
    df_test['HeatingQC']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['HeatingQC'] = label.transform(df_train['HeatingQC'])
df_test['HeatingQC']  = label.transform(df_test['HeatingQC'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['CentralAir']).difference(set(df_train['CentralAir']))
# Out:
# set()

# %%
all_vals = pd.concat([
    df_train['CentralAir'],
    df_test['CentralAir']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['CentralAir'] = label.transform(df_train['CentralAir'])
df_test['CentralAir']  = label.transform(df_test['CentralAir'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['Electrical']).difference(set(df_train['Electrical']))
# Out:
# set()

# %%
all_vals = pd.concat([
    df_train['Electrical'],
    df_test['Electrical']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['Electrical'] = label.transform(df_train['Electrical'])
df_test['Electrical']  = label.transform(df_test['Electrical'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['KitchenQual']).difference(set(df_train['KitchenQual']))
# Out:
# {nan}

# %%
df_train['KitchenQual'] = df_train['KitchenQual'].fillna('None')
df_test['KitchenQual']  = df_test['KitchenQual'].fillna('None')

# %%
all_vals = pd.concat([
    df_train['KitchenQual'],
    df_test['KitchenQual']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['KitchenQual'] = label.transform(df_train['KitchenQual'])
df_test['KitchenQual']  = label.transform(df_test['KitchenQual'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['Functional']).difference(set(df_train['Functional']))
# Out:
# {nan}

# %%
df_train['Functional'] = df_train['Functional'].fillna('None')
df_test['Functional']  = df_test['Functional'].fillna('None')

# %%
all_vals = pd.concat([
    df_train['Functional'],
    df_test['Functional']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['Functional'] = label.transform(df_train['Functional'])
df_test['Functional']  = label.transform(df_test['Functional'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['FireplaceQu']).difference(set(df_train['FireplaceQu']))
# Out:
# set()

# %%
all_vals = pd.concat([
    df_train['FireplaceQu'],
    df_test['FireplaceQu']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['FireplaceQu'] = label.transform(df_train['FireplaceQu'])
df_test['FireplaceQu']  = label.transform(df_test['FireplaceQu'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['GarageType']).difference(set(df_train['GarageType']))
# Out:
# set()

# %%
all_vals = pd.concat([
    df_train['GarageType'],
    df_test['GarageType']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['GarageType'] = label.transform(df_train['GarageType'])
df_test['GarageType']  = label.transform(df_test['GarageType'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['GarageFinish']).difference(set(df_train['GarageFinish']))
# Out:
# set()

# %%
all_vals = pd.concat([
    df_train['GarageFinish'],
    df_test['GarageFinish']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['GarageFinish'] = label.transform(df_train['GarageFinish'])
df_test['GarageFinish']  = label.transform(df_test['GarageFinish'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['GarageQual']).difference(set(df_train['GarageQual']))
# Out:
# set()

# %%
all_vals = pd.concat([
    df_train['GarageQual'],
    df_test['GarageQual']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['GarageQual'] = label.transform(df_train['GarageQual'])
df_test['GarageQual']  = label.transform(df_test['GarageQual'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['GarageCond']).difference(set(df_train['GarageCond']))
# Out:
# set()

# %%
all_vals = pd.concat([
    df_train['GarageCond'],
    df_test['GarageCond']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['GarageCond'] = label.transform(df_train['GarageCond'])
df_test['GarageCond']  = label.transform(df_test['GarageCond'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['PavedDrive']).difference(set(df_train['PavedDrive']))
# Out:
# set()

# %%
all_vals = pd.concat([
    df_train['PavedDrive'],
    df_test['PavedDrive']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['PavedDrive'] = label.transform(df_train['PavedDrive'])
df_test['PavedDrive']  = label.transform(df_test['PavedDrive'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['PoolQC']).difference(set(df_train['PoolQC']))
# Out:
# set()

# %%
all_vals = pd.concat([
    df_train['PoolQC'],
    df_test['PoolQC']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['PoolQC'] = label.transform(df_train['PoolQC'])
df_test['PoolQC']  = label.transform(df_test['PoolQC'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['Fence']).difference(set(df_train['Fence']))
# Out:
# set()

# %%
all_vals = pd.concat([
    df_train['Fence'],
    df_test['Fence']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['Fence'] = label.transform(df_train['Fence'])
df_test['Fence']  = label.transform(df_test['Fence'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['MiscFeature']).difference(set(df_train['MiscFeature']))
# Out:
# set()

# %%
all_vals = pd.concat([
    df_train['MiscFeature'],
    df_test['MiscFeature']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['MiscFeature'] = label.transform(df_train['MiscFeature'])
df_test['MiscFeature']  = label.transform(df_test['MiscFeature'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['SaleType']).difference(set(df_train['SaleType']))
# Out:
# {nan}

# %%
df_train['SaleType'] = df_train['SaleType'].fillna('None')
df_test['SaleType']  = df_test['SaleType'].fillna('None')

# %%
all_vals = pd.concat([
    df_train['SaleType'],
    df_test['SaleType']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['SaleType'] = label.transform(df_train['SaleType'])
df_test['SaleType']  = label.transform(df_test['SaleType'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
set(df_test['SaleCondition']).difference(set(df_train['SaleCondition']))
# Out:
# set()

# %%
all_vals = pd.concat([
    df_train['SaleCondition'],
    df_test['SaleCondition']
])

label.fit(all_vals)
# Out:
# LabelEncoder()

# %%
df_train['SaleCondition'] = label.transform(df_train['SaleCondition'])
df_test['SaleCondition']  = label.transform(df_test['SaleCondition'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
df_train
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0        1          60         4         65.0     8450       1      1
# 1        2          20         4         80.0     9600       1      1
# 2        3          60         4         68.0    11250       1      1
# 3        4          70         4         60.0     9550       1      1
# 4        5          60         4         84.0    14260       1      1
# ...    ...         ...       ...          ...      ...     ...    ...
# 1455  1456          60         4         62.0     7917       1      1
# 1456  1457          20         4         85.0    13175       1      1
# 1457  1458          70         4         66.0     9042       1      1
# 1458  1459          20         4         68.0     9717       1      1
# 1459  1460          20         4         75.0     9937       1      1
#
#       LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
df_test
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0     1461          20         3         80.0    11622       1      1
# 1     1462          20         4         81.0    14267       1      1
# 2     1463          60         4         74.0    13830       1      1
# 3     1464          60         4         78.0     9978       1      1
# 4     1465         120         4         43.0     5005       1      1
# ...    ...         ...       ...          ...      ...     ...    ...
# 1454  2915         160         5         21.0     1936       1      1
# 1455  2916         160         5         21.0     1894       1      1
# 1456  2917          20         4        160.0    20000       1      1
# 1457  2918          85         4         62.0    10441       1      1
# 1458  2919          60         4         74.0     9627       1      1
#
#       LotShape  LandContour  Utilities  ...  ScreenPorch  PoolArea  PoolQC  \
# ...

# %%
X_train = df_train.drop('SalePrice', axis=1)
y_train = df_train['SalePrice']
X_test = df_test.copy()

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
X_train.isna().sum().sort_values(ascending=False).head(10)
# Out:
# LotFrontage    259
# GarageYrBlt     81
# MasVnrArea       8
# Id               0
# LotArea          0
# Street           0
# MSSubClass       0
# MSZoning         0
# LandContour      0
# Utilities        0
# dtype: int64

# %%
num_cols = X_train.select_dtypes(include='number').columns
cat_cols = X_train.select_dtypes(exclude='number').columns

# %%
for col in num_cols:
    X_train[col] = X_train[col].fillna(X_train[col].median())
    X_test[col]  = X_test[col].fillna(X_train[col].median())

# %%
for col in cat_cols:
    X_train[col] = X_train[col].fillna('None')
    X_test[col]  = X_test[col].fillna('None')

# %%
X_train.isna().sum().sum()
# Out:
# np.int64(0)

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
df_sub = pd.read_csv('sample_submission.csv')

# %%
df_sub['number'] = y_pred

# %%
df_sub.to_csv('sub.csv', index=False, index_label=False)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...
